# %% [markdown]
# # Generate cave sets for training and evaluation

# %% [markdown]
# ## Parameters

# %%
output_dir = "caves"
number_of_caves = 300

# %% [markdown]
# ## Generation

# %%
import os
import subprocess

# Define parameter sets
parameter_sets = [
    {
        'count': str(number_of_caves),
        'output_dir': output_dir + '/001',
        'seed': '2',
        'curve_intensity_min': '0',
        'curve_intensity_max': '0',
        'num_dents_min': '0',
        'num_dents_max': '0',
        'offset_magnitude_min': '0',
        'offset_magnitude_max': '0'
    },
     {
        'count': str(number_of_caves),
        'output_dir': output_dir + '/002',
        'seed': '2',
        'curve_intensity_min': '0.3',
        'curve_intensity_max': '0.3',
        'num_dents_min': '0',
        'num_dents_max': '0',
        'offset_magnitude_min': '0',
        'offset_magnitude_max': '0'
    },
    {
        'count': str(number_of_caves),
        'output_dir': output_dir + '/003',
        'seed': '3',
        'curve_intensity_min': '0.5',
        'curve_intensity_max': '0.5',
        'num_dents_min': '0',
        'num_dents_max': '0',
        'offset_magnitude_min': '0',
        'offset_magnitude_max': '0'
    },
    {
        'count': str(number_of_caves),
        'output_dir': output_dir + '/004',
        'seed': '4',
        'curve_intensity_min': '0.5',
        'curve_intensity_max': '0.5',
        'num_dents_min': '0',
        'num_dents_max': '0',
        'offset_magnitude_min': '0.5',
        'offset_magnitude_max': '0.5'
    },
    {
        'count': str(number_of_caves),
        'output_dir': output_dir + '/005',
        'seed': '5',
        'curve_intensity_min': '0.5',
        'curve_intensity_max': '0.5',
        'num_dents_min': '0',
        'num_dents_max': '0',
        'offset_magnitude_min': '1.0',
        'offset_magnitude_max': '1.0'
    },
        {
        'count': str(number_of_caves),
        'output_dir': output_dir + '/006',
        'seed': '6',
        'curve_intensity_min': '0.5',
        'curve_intensity_max': '0.5',
        'num_dents_min': '0',
        'num_dents_max': '0',
        'offset_magnitude_min': '1.5',
        'offset_magnitude_max': '1.5'
    },
        {
        'count': str(number_of_caves),
        'output_dir': output_dir + '/007',
        'seed': '7',
        'curve_intensity_min': '0.5',
        'curve_intensity_max': '0.5',
        'num_dents_min': '1',
        'num_dents_max': '1',
        'offset_magnitude_min': '1.5',
        'offset_magnitude_max': '1.5'
    },
    {
        'count': str(number_of_caves),
        'output_dir': output_dir + '/008',
        'seed': '8',
        'curve_intensity_min': '0.5',
        'curve_intensity_max': '0.5',
        'num_dents_min': '2',
        'num_dents_max': '2',
        'offset_magnitude_min': '1.5',
        'offset_magnitude_max': '1.5'
    },
    {
        'count': str(number_of_caves),
        'output_dir': output_dir + '/009',
        'seed': '9',
        'curve_intensity_min': '0.5',
        'curve_intensity_max': '0.5',
        'num_dents_min': '3',
        'num_dents_max': '3',
        'offset_magnitude_min': '1.5',
        'offset_magnitude_max': '1.5'
    },
]

# Get the current working directory and navigate to the script
current_dir = os.getcwd()
script_path = os.path.join(current_dir, 'utils', 'cave_generator.py')

# Execute the cave generator script for each parameter set
for params in parameter_sets:
    subprocess.run([
        'python', script_path,
        '--count', params['count'],
        '--output-dir', params['output_dir'],
        '--seed', params['seed'],
        '--curve-intensity-min', params['curve_intensity_min'],
        '--curve-intensity-max', params['curve_intensity_max'],
        '--num-dents-min', params['num_dents_min'],
        '--num-dents-max', params['num_dents_max'],
        '--offset-magnitude-min', params['offset_magnitude_min'],
        '--offset-magnitude-max', params['offset_magnitude_max']
    ])
# Out:
# Generating caves:  32%|███▏      | 97/300 [02:50<05:57,  1.76s/cave]
# Traceback (most recent call last):
#   File "/home/ga53voq/master_thesis/tasks/cave_exploration/environment/utils/cave_generator.py", line 547, in <module>
#   File "/home/ga53voq/master_thesis/tasks/cave_exploration/environment/utils/cave_generator.py", line 458, in create_cave
#   File "/home/ga53voq/.conda/envs/pyenv/lib/python3.12/site-packages/trimesh/base.py", line 2830, in export
#     return export_mesh(mesh=self, file_obj=file_obj, file_type=file_type, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ga53voq/.conda/envs/pyenv/lib/python3.12/site-packages/trimesh/exchange/export.py", line 55, in export_mesh
#     file_obj = open(file_path, "wb")
#                ^^^^^^^^^^^^^^^^^^^^^
# ...
