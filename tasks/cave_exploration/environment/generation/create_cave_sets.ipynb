# %% [markdown]
# # Generate cave sets for training and evaluation

# %% [markdown]
# ## Parameters

# %%
output_dir = "caves"
number_of_caves = 300

# %% [markdown]
# ## Generation

# %%
import os
import subprocess

# Define parameter sets
parameter_sets = [
    {
        'count': str(number_of_caves),
        'output_dir': output_dir + '/001',
        'seed': '2',
        'curve_intensity_min': '0',
        'curve_intensity_max': '0',
        'num_dents_min': '0',
        'num_dents_max': '0',
        'offset_magnitude_min': '0',
        'offset_magnitude_max': '0'
    },
     {
        'count': str(number_of_caves),
        'output_dir': output_dir + '/002',
        'seed': '2',
        'curve_intensity_min': '0.3',
        'curve_intensity_max': '0.3',
        'num_dents_min': '0',
        'num_dents_max': '0',
        'offset_magnitude_min': '0',
        'offset_magnitude_max': '0'
    },
    {
        'count': str(number_of_caves),
        'output_dir': output_dir + '/003',
        'seed': '3',
        'curve_intensity_min': '0.5',
        'curve_intensity_max': '0.5',
        'num_dents_min': '0',
        'num_dents_max': '0',
        'offset_magnitude_min': '0',
        'offset_magnitude_max': '0'
    },
    {
        'count': str(number_of_caves),
        'output_dir': output_dir + '/004',
        'seed': '4',
        'curve_intensity_min': '0.5',
        'curve_intensity_max': '0.5',
        'num_dents_min': '0',
        'num_dents_max': '0',
        'offset_magnitude_min': '0.5',
        'offset_magnitude_max': '0.5'
    },
    {
        'count': str(number_of_caves),
        'output_dir': output_dir + '/005',
        'seed': '5',
        'curve_intensity_min': '0.5',
        'curve_intensity_max': '0.5',
        'num_dents_min': '0',
        'num_dents_max': '0',
        'offset_magnitude_min': '1.0',
        'offset_magnitude_max': '1.0'
    },
        {
        'count': str(number_of_caves),
        'output_dir': output_dir + '/006',
        'seed': '6',
        'curve_intensity_min': '0.5',
        'curve_intensity_max': '0.5',
        'num_dents_min': '0',
        'num_dents_max': '0',
        'offset_magnitude_min': '1.5',
        'offset_magnitude_max': '1.5'
    },
        {
        'count': str(number_of_caves),
        'output_dir': output_dir + '/007',
        'seed': '7',
        'curve_intensity_min': '0.5',
        'curve_intensity_max': '0.5',
        'num_dents_min': '1',
        'num_dents_max': '1',
        'offset_magnitude_min': '1.5',
        'offset_magnitude_max': '1.5'
    },
    {
        'count': str(number_of_caves),
        'output_dir': output_dir + '/008',
        'seed': '8',
        'curve_intensity_min': '0.5',
        'curve_intensity_max': '0.5',
        'num_dents_min': '2',
        'num_dents_max': '2',
        'offset_magnitude_min': '1.5',
        'offset_magnitude_max': '1.5'
    },
    {
        'count': str(number_of_caves),
        'output_dir': output_dir + '/009',
        'seed': '9',
        'curve_intensity_min': '0.5',
        'curve_intensity_max': '0.5',
        'num_dents_min': '3',
        'num_dents_max': '3',
        'offset_magnitude_min': '1.5',
        'offset_magnitude_max': '1.5'
    },
]

# Get the current working directory and navigate to the script
current_dir = os.getcwd()
script_path = os.path.join(current_dir, 'cave_generator.py')

# Execute the cave generator script for each parameter set
for params in parameter_sets:
    subprocess.run([
        'python', script_path,
        '--count', params['count'],
        '--output-dir', params['output_dir'],
        '--seed', params['seed'],
        '--curve-intensity-min', params['curve_intensity_min'],
        '--curve-intensity-max', params['curve_intensity_max'],
        '--num-dents-min', params['num_dents_min'],
        '--num-dents-max', params['num_dents_max'],
        '--offset-magnitude-min', params['offset_magnitude_min'],
        '--offset-magnitude-max', params['offset_magnitude_max']
    ])
# Out:
# Generating caves: 100%|██████████| 300/300 [09:30<00:00,  1.90s/cave]
# Generated 300 caves with voxel size 0.2m using seed 2.
# Length of caves: 20.0 meters
# Curve intensity range: [0.0, 0.0]
# Number of dents range: [0, 0]
# Offset magnitude range: [0.0, 0.0]
# Summary saved to caves/001/caves_summary.json
# Generating caves: 100%|██████████| 300/300 [09:32<00:00,  1.91s/cave]
# Generated 300 caves with voxel size 0.2m using seed 2.
# Length of caves: 20.0 meters
# Curve intensity range: [0.3, 0.3]
# Number of dents range: [0, 0]
# Offset magnitude range: [0.0, 0.0]
# Summary saved to caves/002/caves_summary.json
# Generating caves: 100%|██████████| 300/300 [09:45<00:00,  1.95s/cave]
# Generated 300 caves with voxel size 0.2m using seed 3.
# Length of caves: 20.0 meters
# Curve intensity range: [0.5, 0.5]
# Number of dents range: [0, 0]
# Offset magnitude range: [0.0, 0.0]
# Summary saved to caves/003/caves_summary.json
# Generating caves: 100%|██████████| 300/300 [09:51<00:00,  1.97s/cave]
# Generated 300 caves with voxel size 0.2m using seed 4.
# Length of caves: 20.0 meters
# Curve intensity range: [0.5, 0.5]
# Number of dents range: [0, 0]
# Offset magnitude range: [0.5, 0.5]
# Summary saved to caves/004/caves_summary.json
# Generating caves: 100%|██████████| 300/300 [09:57<00:00,  1.99s/cave]
# Generated 300 caves with voxel size 0.2m using seed 5.
# Length of caves: 20.0 meters
# Curve intensity range: [0.5, 0.5]
# Number of dents range: [0, 0]
# Offset magnitude range: [1.0, 1.0]
# Summary saved to caves/005/caves_summary.json
# Generating caves: 100%|██████████| 300/300 [09:50<00:00,  1.97s/cave]
# Generated 300 caves with voxel size 0.2m using seed 6.
# Length of caves: 20.0 meters
# Curve intensity range: [0.5, 0.5]
# Number of dents range: [0, 0]
# Offset magnitude range: [1.5, 1.5]
# Summary saved to caves/006/caves_summary.json
# Generating caves: 100%|██████████| 300/300 [09:54<00:00,  1.98s/cave]
# Generated 300 caves with voxel size 0.2m using seed 7.
# Length of caves: 20.0 meters
# Curve intensity range: [0.5, 0.5]
# Number of dents range: [1, 1]
# Offset magnitude range: [1.5, 1.5]
# Summary saved to caves/007/caves_summary.json
# Generating caves: 100%|██████████| 300/300 [10:08<00:00,  2.03s/cave]
# Generated 300 caves with voxel size 0.2m using seed 8.
# Length of caves: 20.0 meters
# Curve intensity range: [0.5, 0.5]
# Number of dents range: [2, 2]
# Offset magnitude range: [1.5, 1.5]
# Summary saved to caves/008/caves_summary.json
# Generating caves: 100%|█████████▉| 299/300 [09:46<00:01,  1.98s/cave]
# Generated 300 caves with voxel size 0.2m using seed 9.
# Length of caves: 20.0 meters
# Curve intensity range: [0.5, 0.5]
# Number of dents range: [3, 3]
# Offset magnitude range: [1.5, 1.5]
# Summary saved to caves/009/caves_summary.json
# Generating caves: 100%|██████████| 300/300 [09:48<00:00,  1.96s/cave]
